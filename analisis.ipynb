# %%
import pandas as pd

# %%
env_path = "/home/aguilar/Projects/polnet"

# %%
df = pd.read_csv(f"{env_path}/data/data_generated/250_tomos/tomos_motif_list.csv",
                 delimiter="\t")

# %%
df.columns
# Out:
# Index(['Density', 'Micrographs', 'PolyData', 'Tomo3D', 'Type', 'Label', 'Code',
#        'Polymer', 'X', 'Y', 'Z', 'Q1', 'Q2', 'Q3', 'Q4'],
#       dtype='object')

# %%
df.head(1)
# Out:
#                                              Density  \
# 0  /home/aguilar/Projects/polnet/data/data_genera...
#
#                                          Micrographs  \
# 0  /home/aguilar/Projects/polnet/data/data_genera...
#
#                                             PolyData  \
# 0  /home/aguilar/Projects/polnet/data/data_genera...
#
#                                               Tomo3D      Type  Label  \
# 0  /home/aguilar/Projects/polnet/data/data_genera...  Membrane      1
#
#       Code  Polymer      X       Y           Z        Q1        Q2        Q3  \
# 0  ellipse        0  890.0  1760.0  769.993164  0.047152  0.136944  0.989456
#
#     Q4
# 0  0.0

# %%
tomos = set(df['Tomo3D'].tolist())

# %%
df["Code"].unique()
# Out:
# array(['ellipse', 'pdb_6pxm', 'pdb_1f4a', 'pdb_6qzp', 'pdb_7n4y',
#        'pdb_8tux'], dtype=object)
